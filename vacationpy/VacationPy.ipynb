# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from API_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# File to Load (Remember to Change These)
city_weather = "city_weather.csv"

# Read Data File and store into two seperate Pandas DataFrames
city_data = pd.read_csv(city_weather)

# %%
city_data
# Out:
#     Unnamed: 0          name    lat    long  max_temp  humidity  clouds  \
# 0            0       qaanaaq  77.48  -69.36     11.77        78       0
# 1            1        albany  42.60  -73.97     64.99        54      90
# 2            2         otavi -19.65   17.33     66.13        26       0
# 3            3   grand gaube -20.01   57.66     73.99        84      15
# 4            4     busselton -33.65  115.33     51.01        89       1
# ..         ...           ...    ...     ...       ...       ...     ...
# 73          73  punta arenas -53.15  -70.92     46.40        49     100
# 74          74        noumea -22.28  166.46     73.99        88      75
# 75          75        laguna  38.42 -121.42     80.60        32       1
# 76          76      luderitz -26.65   15.16     60.49        79       0
# 77          77   pak phanang   8.35  100.20     77.74        83     100
#
#     wind_speed country        date
# 0         5.01      GL  1602105197
# 1         5.82      US  1602105140
# 2         8.93     NaN  1602105197
# 3         5.01      MU  1602105198
# 4         6.93      AU  1602105198
# ..         ...     ...         ...
# 73       17.22      CL  1602105198
# 74        2.24      NC  1602105205
# 75        4.70      US  1602105205
# 76       17.27     NaN  1602105205
# 77        6.98      TH  1602104945
#
# [78 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key= g_key)
# Heatmap of humidity
locations = city_data[["lat", "long"]]
humidity = city_data["humidity"]
fig = gmaps.figure(center=(39.106667,-94.676392), zoom_level=2)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=5)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
data_filtered = city_data[city_data["max_temp"] <= 70]
data_filtered
# Out:
#     Unnamed: 0            name    lat    long  max_temp  humidity  clouds  \
# 0            0         qaanaaq  77.48  -69.36     11.77        78       0
# 1            1          albany  42.60  -73.97     64.99        54      90
# 2            2           otavi -19.65   17.33     66.13        26       0
# 4            4       busselton -33.65  115.33     51.01        89       1
# 5            5   dalnerechensk  45.93  133.72     39.58        86       0
# 6            6       neyshabur  36.21   58.80     52.84        41       0
# 8            8   alice springs -23.70  133.88     48.20        93       0
# 9            9       jamestown  42.10  -79.24     61.00        59      40
# 12          12           vaini -21.20 -175.20     69.80       100      90
# 14          14     moshenskoye  58.51   34.59     50.59        92     100
# 16          16         kamenka  51.32   42.77     48.61        51      93
# 17          17       esperance -33.87  121.90     51.80        62      94
# 18          18    longyearbyen  78.22   15.64     33.80       100      40
# 19          19           heihe  50.24  127.49     28.40        92       0
# 21          21        coos bay  43.37 -124.22     61.00        87      90
# 22          22          bethel  41.37  -73.41     63.00        82      80
# 23          23        tasiilaq  65.61  -37.64     35.60        94      99
# 25          25          lashio  22.93   97.75     65.70        98      25
# 30          30        thompson  55.74  -97.86     35.60        64      75
# 31          31  port elizabeth -33.92   25.57     60.80        93      40
# 32          32          dikson  73.51   80.55     36.90        96     100
# 34          34        katsuura  35.13  140.30     60.01       100      75
# 36          36          palmer  42.16  -72.33     68.00        52      75
# 39          39        hushitai  41.93  123.51     50.00        87       0
# 40          40          barrow  71.29 -156.79     30.20        80      90
# 41          41         ushuaia -54.80  -68.30     42.80        64      75
# 45          45     port alfred -33.59   26.89     65.84        83       0
# 47          47    kruisfontein -34.00   24.73     57.99        92       2
# 49          49          torbay  47.67  -52.73     54.00        87      90
# 50          50       saskylakh  71.92  114.08      9.66        94      36
# 51          51     pangnirtung  66.15  -65.71     37.40        51      90
# 54          54         paranga  56.70   49.40     47.48        81     100
# 57          57        cepelare  41.73   24.68     69.01        72     100
# 58          58           arman  59.70  150.17     35.96        71      36
# 59          59       tazovskiy  67.47   78.70     36.32        97     100
# 61          61          hobart -42.88  147.33     53.60        76      75
# 62          62      mandalgovi  45.76  106.27     46.08        53     100
# 63          63     east london -33.02   27.91     68.94        85       0
# 64          64            lebu -37.62  -73.65     51.91        70     100
# 65          65            esso  55.93  158.70     33.39        89      49
# 68          68      kaitangata -46.28  169.85     48.00        62      95
# 69          69   mar del plata -38.00  -57.56     60.80        36       0
# 70          70            lata  40.16   -8.33     64.00        88      33
# 71          71  vestmannaeyjar  63.44  -20.27     43.36        74       1
# 72          72            hami  42.80   93.45     44.10        49       0
# 73          73    punta arenas -53.15  -70.92     46.40        49     100
# 76          76        luderitz -26.65   15.16     60.49        79       0
#
#     wind_speed country        date
# 0         5.01      GL  1602105197
# 1         5.82      US  1602105140
# 2         8.93     NaN  1602105197
# 4         6.93      AU  1602105198
# 5         2.77      RU  1602105198
# 6         3.98      IR  1602105086
# 8         8.61      AU  1602105198
# 9        24.16      US  1602105189
# 12        8.05      TO  1602105199
# 14        6.69      RU  1602105199
# 16        8.30      RU  1602105199
# 17        5.82      AU  1602105064
# 18       17.22      SJ  1602105199
# 19        2.64      CN  1602105199
# 21        5.28      US  1602105027
# 22        1.01      US  1602105098
# 23        3.36      GL  1602105200
# 25        1.72      MM  1602105200
# 30       11.41      CA  1602105200
# 31        9.17      ZA  1602105201
# 32       25.12      RU  1602105201
# 34       16.11      JP  1602105201
# 36       18.34      US  1602105201
# 39        6.71      CN  1602105201
# 40       19.46      US  1602105202
# 41       14.99      AR  1602105138
# 45        2.15      ZA  1602105202
# 47        5.70      ZA  1602105202
# 49       24.16      CA  1602105202
# 50        8.37      RU  1602105203
# 51       19.46      CA  1602105203
# 54        9.04      RU  1602105203
# 57        2.24      BG  1602105203
# 58        8.08      RU  1602105203
# 59       18.75      RU  1602105203
# 61        8.05      AU  1602105186
# 62       16.42      MN  1602105204
# 63        6.24      ZA  1602105204
# 64       12.28      CL  1602105204
# 65       10.83      RU  1602105204
# 68        3.00      NZ  1602105204
# 69       11.41      AR  1602105129
# 70        1.52      PT  1602105204
# 71        7.87      IS  1602105204
# 72        9.08      CN  1602105205
# 73       17.22      CL  1602105198
# 76       17.27     NaN  1602105205

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = data_filtered.copy()
hotel_df["Hotel Name"] = ""

# Set parameters to search for a hotel
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key
     }

# %%
# Iterate through 
for index, row in hotel_df.iterrows():
    latitude = row["lat"]
    longitude = row["long"]
    params["location"] = f"{latitude}, {longitude}" 
    # Use the search term: "Hotel" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Grab the first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
name_address
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAAC7rbzeR-VQVQs08wSbbOduzcXqUh9tZjBy-dCqgDAaM8tfBwKXxF_HwimMynbNn1gAF6ensvTtGee8PJzrVN2NAZbXXHj6RUZnCCeRgnuJYqSCRKES-rQ7vnPpZpcRXzP1SdHJ0ouJD-RRVJnarEVCiCCRh8i2kSLSDxTXctbJz8neFNpAeliJWp7ZSyqvDwOCEiff3bCI9-W18LK8O20YuXJocIiwtgFYS6AVmjPnU4m5GrKRNjsLF63QukH0Gsk3xx3n5102ES-1qtUbIwM_xasPwe5_zv9nZ_4--ZLIvL4tyUtF3bA8t8fV1-_eR7VcVglKSqf0bC3EmCf3xSSfZzIGmSrrNnPIIv3J3i_MeNW8FsQxLpsNqhqHWc8VjuhIQ4jjMzJuW5WQW7YVXmgq2ahoUtKpN6enF5j9Xk0TfGAiIQU4xZTQ',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.652957, 'lng': 15.14962},
#     'viewport': {'northeast': {'lat': -26.6516987197085,
#       'lng': 15.1510167802915},
#      'southwest': {'lat': -26.6543966802915, 'lng': 15.1483188197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'LÜDERITZ NEST HOTEL',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 702,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102137261103382456577">LÜDERITZ NEST HOTEL</a>'],
#      'photo_reference': 'CmRaAAAA7Xjdy1fD9KIGFH5mr4VHFBymFwCE_dF0fAk23Gg-dj3ez7JorlHyJApHqNjFJsO_a8NR04HxFhzEmH6eXG5uR2SNPJxAGh59IjP7BhBaMZvPvOKj41UqqH3EAA573K0NEhCCVz6UX9_jAHH9D4UjAs6RGhQ5KqxqmMN4gNTDBE22Y3b6Hv_Isw',
#      'width': 1024}],
#    'place_id': 'ChIJ9QHv-ZXmaxwRdYOLHfQaMLc',
#    'plus_code': {'compound_code': '84WX+RR Luderitz, Namibia',
#     'global_code': '5F5Q84WX+RR'},
#    'rating': 4.2,
#    'reference': 'ChIJ9QHv-ZXmaxwRdYOLHfQaMLc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 522,
#    'vicinity': '820 Dias Street, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.64507, 'lng': 15.158333},
#     'viewport': {'northeast': {'lat': -26.6436567697085,
#       'lng': 15.1596060302915},
#      'southwest': {'lat': -26.6463547302915, 'lng': 15.1569080697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Lüderitz Zum Sperrgebiet',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111709360212055880555">Karl Svozil</a>'],
#      'photo_reference': 'CmRaAAAATValSpovub_1eqBZxk3tJQAiKgtMPuw2QPLdkSBaSPhvmC2dXA1q-PSCgNkzjq-FHc3UnnGCEcnJNtF5xLxsyGptqL6h6u-6NNqc3y3eWmU65hJD2_7Gj8FrmSCsW1WMEhAahKtmxHUIDasnhCwF3jzEGhRgm3SqJRvz4wZRDs-xaD7zZUHtNA',
#      'width': 6000}],
#    'place_id': 'ChIJdysDhJrmaxwRSZiJwkur1wo',
#    'plus_code': {'compound_code': '9535+X8 Luderitz, Namibia',
#     'global_code': '5F5Q9535+X8'},
#    'rating': 3.3,
#    'reference': 'ChIJdysDhJrmaxwRSZiJwkur1wo',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 101,
#    'vicinity': 'Woermann Street, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.642038, 'lng': 15.163908},
#     'viewport': {'northeast': {'lat': -26.6407902697085,
#       'lng': 15.1652791802915},
#      'southwest': {'lat': -26.6434882302915, 'lng': 15.1625812197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Dieash Self Catering cc',
#    'place_id': 'ChIJ8f___4TmaxwRkEuzu8q7U14',
#    'plus_code': {'compound_code': '9557+5H Luderitz, Namibia',
#     'global_code': '5F5Q9557+5H'},
#    'reference': 'ChIJ8f___4TmaxwRkEuzu8q7U14',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Quartz street, Agata Park, Erf 698 Erf 698 - Dieash Self Catering cc, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6484776, 'lng': 15.153797},
#     'viewport': {'northeast': {'lat': -26.6471164197085,
#       'lng': 15.1552131302915},
#      'southwest': {'lat': -26.6498143802915, 'lng': 15.1525151697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Haus Sandrose',
#    'photos': [{'height': 3265,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115514274422440655699">Swen Schindowski</a>'],
#      'photo_reference': 'CmRaAAAAfJSIz0Q9Op_39QhZ-cfFO_whFXxkpVvnGhCcPriPfvuD-RLvrS6iy6F7PdDLpgnHmWTNdYcn-jl0CWIm64eBsZ3uA-FKU3N8ptIvAuUlPpbUHmLkD4ZZlM18FLZ4NgnTEhASvmthj12YYSA-H_wyHn8kGhSQS6Atn6HIntW1GCKkL_oK9Z8xRw',
#      'width': 4898}],
#    'place_id': 'ChIJfTY5IpfmaxwRgAERIptSUak',
#    'plus_code': {'compound_code': '9523+JG Luderitz, Namibia',
#     'global_code': '5F5Q9523+JG'},
#    'rating': 4.6,
#    'reference': 'ChIJfTY5IpfmaxwRgAERIptSUak',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 34,
#    'vicinity': 'Bismarck Street, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6479382, 'lng': 15.1529253},
#     'viewport': {'northeast': {'lat': -26.6464675197085,
#       'lng': 15.1543469302915},
#      'southwest': {'lat': -26.64916548029151, 'lng': 15.1516489697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Kratzplatz',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109157457723656646473">Jesús Lpa</a>'],
#      'photo_reference': 'CmRaAAAA3IQIHDLSvwKTTe9t7iro2X02FoivokJMSQcI5_0Bn01aO6knPhqGuPT7If67b7E05ucb4XIfMAZeTWZHXOlQqMEcWU71XvI1S513y92QvmTW1NRtxyN_sZTvETumWzgeEhDP5n7j-hRJS0YdUmJVcgCEGhRYAPnatm157LhC6iIEKog2F0cTIA',
#      'width': 4000}],
#    'place_id': 'ChIJISfADZfmaxwR3fOPlikrZ3w',
#    'plus_code': {'compound_code': '9523+R5 Luderitz, Namibia',
#     'global_code': '5F5Q9523+R5'},
#    'rating': 4.3,
#    'reference': 'ChIJISfADZfmaxwR3fOPlikrZ3w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 138,
#    'vicinity': '5 Nachtigall Street, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6374496, 'lng': 15.1521711},
#     'viewport': {'northeast': {'lat': -26.6361006197085,
#       'lng': 15.1534653302915},
#      'southwest': {'lat': -26.6387985802915, 'lng': 15.1507673697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/camping-71.png',
#    'name': 'Shark Island Camp Site',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113024584737294169010">Chris Vermaak</a>'],
#      'photo_reference': 'CmRaAAAA5y4HKMfHJ-O9-wUyqhcIBaxWq0o-n-TWAYNpN-aWSON8xyJlGRWmx3zsxwnN2HZtPoNIzQWlFaHpJrvJwcMOHoGtFOoMbeaa3nhDfxKPBtbSfAbL4h8_TzDpoN_RAws5EhB_wC6IzC9VpEHX52Gr5smxGhTv_OoZU3rw0ypCLYNZlJu7xKweng',
#      'width': 5333}],
#    'place_id': 'ChIJr1xGVZ7maxwRB9onhpEV9cY',
#    'plus_code': {'compound_code': '9572+2V Luderitz, Namibia',
#     'global_code': '5F5Q9572+2V'},
#    'rating': 3.8,
#    'reference': 'ChIJr1xGVZ7maxwRB9onhpEV9cY',
#    'scope': 'GOOGLE',
#    'types': ['campground',
#     'lodging',
#     'park',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 61,
#    'vicinity': 'Kreplin, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.64793999999999, 'lng': 15.1565157},
#     'viewport': {'northeast': {'lat': -26.6465483697085,
#       'lng': 15.1579234802915},
#      'southwest': {'lat': -26.6492463302915, 'lng': 15.1552255197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Alte Villa',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118421660957668063305">Oliver Plank</a>'],
#      'photo_reference': 'CmRaAAAABfiK1xsw2Dv8ND4xxZMCuObeBZMpGmCYNn9me-4UdrbbieakSiJ_kMLXD2iHa9bRptuQG07gtf-zQJ1vZ862BLBabRvkSCPdg1sbYmuy_GT6gnZ2rQp17PLoxoGoROJkEhDFSkxgdTPyauaE3i8v_Yi-GhQHSPBO8Air8_1OX6A4KhZRar9bSw',
#      'width': 4000}],
#    'place_id': 'ChIJfx7R2JDmaxwRiI7Ydtn_4O0',
#    'plus_code': {'compound_code': '9524+RJ Luderitz, Namibia',
#     'global_code': '5F5Q9524+RJ'},
#    'rating': 4.3,
#    'reference': 'ChIJfx7R2JDmaxwRiI7Ydtn_4O0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 56,
#    'vicinity': 'Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6428049, 'lng': 15.1642992},
#     'viewport': {'northeast': {'lat': -26.6413126197085,
#       'lng': 15.1659356802915},
#      'southwest': {'lat': -26.6440105802915, 'lng': 15.1632377197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': "Timo's Lodge",
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103521886948166160209">Rudi Breit</a>'],
#      'photo_reference': 'CmRaAAAAHZQX4FDwC18kFLyB19ilxq9vBW_Lufjo-URXlTKZmKNwC4htFO8ZrCqMqgJ_V-Z57MZS4gAMqY_u5dGor61YyZaNNdHlhGzC9jGMeXYhOxtA7g9vl46sueDv_JCb_t4aEhDOUg3j4O0bmhkavnuYlm9zGhRDJNLd7EzyW9ngrtby7UvmHuKn4Q',
#      'width': 4032}],
#    'place_id': 'ChIJF_jdpYXmaxwRTvUEgcPBKFI',
#    'plus_code': {'compound_code': '9547+VP Luderitz, Namibia',
#     'global_code': '5F5Q9547+VP'},
#    'rating': 4,
#    'reference': 'ChIJF_jdpYXmaxwRTvUEgcPBKFI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 154,
#    'vicinity': 'Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6491464, 'lng': 15.1581341},
#     'viewport': {'northeast': {'lat': -26.6478032197085,
#       'lng': 15.1594484302915},
#      'southwest': {'lat': -26.6505011802915, 'lng': 15.1567504697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Roubix Den Self Catering',
#    'photos': [{'height': 2976,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107610037459946695021">Susan Pretorius</a>'],
#      'photo_reference': 'CmRaAAAAvMeWalE5XfGesgSGsuAsspqTC9tw1FnmkNYf3PtV5HzT9QstIlbPtLx3drfVHpG6HH1ZpCL_Rs9gxIX8x79z6DHXzLGCbzSS2Bya4QIaEy1EYCXl3cqi2UZ8PXfRDuXNEhBAWoImC6U6iFBAAdM5buHJGhR0JR5qeWrS3Rpcyev8QNwW4xd64A',
#      'width': 2976}],
#    'place_id': 'ChIJXcSGA9HnaxwRnV-IBpOleGk',
#    'plus_code': {'compound_code': '9525+87 Luderitz, Namibia',
#     'global_code': '5F5Q9525+87'},
#    'reference': 'ChIJXcSGA9HnaxwRnV-IBpOleGk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'erf 52 Vogelsang Street, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.65213, 'lng': 15.1583738},
#     'viewport': {'northeast': {'lat': -26.6508132697085,
#       'lng': 15.1596819802915},
#      'southwest': {'lat': -26.6535112302915, 'lng': 15.1569840197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Oars Guesthouse',
#    'place_id': 'ChIJ4Wpl-tXnaxwRgZXkiM2Zg2Q',
#    'plus_code': {'compound_code': '85X5+48 Luderitz, Namibia',
#     'global_code': '5F5Q85X5+48'},
#    'rating': 3.3,
#    'reference': 'ChIJ4Wpl-tXnaxwRgZXkiM2Zg2Q',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6519216, 'lng': 15.1571457},
#     'viewport': {'northeast': {'lat': -26.6504369697085,
#       'lng': 15.1585915802915},
#      'southwest': {'lat': -26.6531349302915, 'lng': 15.1558936197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Prospectors Inn Hotel',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 809,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105873808453299249853">Prospectors Inn Hotel</a>'],
#      'photo_reference': 'CmRaAAAAUYHmWFmgWAZFRo8qtrFpVFsRT_U4uIs8hEoSeG5kBeSLrNaWktxmW0m4YkE-WnTED74qtUxuFNgREgUj3TTSwKYwceUeDMLtYdpyc5yrkw0urEuYhjqUWx8xV9-g_fcPEhCP-dnFa-YHzI48w8mS6zmqGhQcLwDhQuwbDpxWxT-Ghvi0-4f6Cg',
#      'width': 1080}],
#    'place_id': 'ChIJy5RiDvjnaxwRzyQU8kR56_Y',
#    'plus_code': {'compound_code': '85X4+6V Luderitz, Namibia',
#     'global_code': '5F5Q85X4+6V'},
#    'rating': 5,
#    'reference': 'ChIJy5RiDvjnaxwRzyQU8kR56_Y',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 17,
#    'vicinity': 'B4 (Entrance at Trentyre gate, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.652387, 'lng': 15.157012},
#     'viewport': {'northeast': {'lat': -26.6512240697085,
#       'lng': 15.1585375302915},
#      'southwest': {'lat': -26.6539220302915, 'lng': 15.1558395697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Villelodge Accommodation',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2232,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107660823865952753088">Villelodge Accommodation</a>'],
#      'photo_reference': 'CmRaAAAAxQDvPFpjZ9v9o5OmtlspXl9piFUtFie4lVfPFmKqDpnkM68zCCS8KF5g-1qqGIEVus9abfGXYj9jdZLP1iyqXum_A5d97QNgfkshYbleDCHO2qn2EK_vjzk7yqNXwkbLEhDEHW3RSPPIP-JXxas4oSTTGhRYUF5xAejK0FlWxEQW2-eiK9VW2g',
#      'width': 2976}],
#    'place_id': 'ChIJ05JtxJPmaxwRgPaDUCuAuxg',
#    'plus_code': {'compound_code': '85X4+2R Luderitz, Namibia',
#     'global_code': '5F5Q85X4+2R'},
#    'rating': 4.3,
#    'reference': 'ChIJ05JtxJPmaxwRgPaDUCuAuxg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 69,
#    'vicinity': 'Bay Road, Burenkamp, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6511841, 'lng': 15.1556959},
#     'viewport': {'northeast': {'lat': -26.6498257697085,
#       'lng': 15.1569466302915},
#      'southwest': {'lat': -26.6525237302915, 'lng': 15.1542486697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Obelix Guesthouse',
#    'photos': [{'height': 1200,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108718573325798298269">Karin Silk</a>'],
#      'photo_reference': 'CmRaAAAAqDXnvcn8GMU3maDAxSZSdrFHVmUo3OOXaufIVnnIlhg4t9OPsC-iHnfPFRJZ5rDM99CQ39uINpEBs-obeEEzmWG2KHsEvagnNwvvwMfevyoXY3uRnb_x3W_4C5xyK69iEhCNzBMcB_nVxj4mEeksTIwJGhRsjyCCXrB0GIxYbPOmMd8xNiQIiw',
#      'width': 1600}],
#    'place_id': 'ChIJ_UjSUJHmaxwRUrPp2y0la48',
#    'plus_code': {'compound_code': '85X4+G7 Luderitz, Namibia',
#     'global_code': '5F5Q85X4+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJ_UjSUJHmaxwRUrPp2y0la48',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 164,
#    'vicinity': 'Namibia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.652644, 'lng': 15.1564205},
#     'viewport': {'northeast': {'lat': -26.6512954697085,
#       'lng': 15.1577689802915},
#      'southwest': {'lat': -26.6539934302915, 'lng': 15.1550710197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Prospectus Inn Restuarsnt',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112038380279708112147">Maritza Morgan</a>'],
#      'photo_reference': 'CmRaAAAA9wR0rnFJ-qDLtjmt21blSTFS8r5JtJE8AzsJAx9aOeMpfAqErLx2BgRvuyaZrRsNb9hr5jXhH2EMxC-GgjIN7GxCwdlB4gY--AEZQe2svb2wf_sBizE_ymgPMHQZLz5TEhBlho1l8mWvuQH2EcJ7DX2HGhTZQLI7sO6o5JQhxF9SKh1kN6MktA',
#      'width': 760}],
#    'place_id': 'ChIJ-0qbcQ7naxwR4U_Zh9aJvMA',
#    'plus_code': {'compound_code': '85W4+WH Luderitz, Namibia',
#     'global_code': '5F5Q85W4+WH'},
#    'rating': 5,
#    'reference': 'ChIJ-0qbcQ7naxwR4U_Zh9aJvMA',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'B4, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6479849, 'lng': 15.154723},
#     'viewport': {'northeast': {'lat': -26.6465787197085,
#       'lng': 15.1559985302915},
#      'southwest': {'lat': -26.6492766802915, 'lng': 15.1533005697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Element Riders Backpackers',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 986,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110860981200352721272">Element Riders Backpackers</a>'],
#      'photo_reference': 'CmRaAAAAEQ36XsgpAk-jLQ9ZGmdIBIB5pCY1dsCyADBN5TG80FinmcV4FnRIG609IqXhdHUZOrf0s-BeU3iay61tNtWONDFBOHf3BN7BZ2HXgLGOJVo0gHP4kZmhGkuCTeegvFW6EhA6_SyZFCGNqLm3NAy91P-QGhTFGoxIw1vy2w1vUrk1qMW3B1JHww',
#      'width': 1476}],
#    'place_id': 'ChIJI6WDMZfmaxwRtQMiSpITeoo',
#    'plus_code': {'compound_code': '9523+RV Luderitz, Namibia',
#     'global_code': '5F5Q9523+RV'},
#    'rating': 4.1,
#    'reference': 'ChIJI6WDMZfmaxwRtQMiSpITeoo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 42,
#    'vicinity': '7 Schinz Street, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6479418, 'lng': 15.1545459},
#     'viewport': {'northeast': {'lat': -26.6465961197085,
#       'lng': 15.1558991302915},
#      'southwest': {'lat': -26.6492940802915, 'lng': 15.1532011697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': '7 Schinz Street',
#    'place_id': 'ChIJNbXruHbnaxwRmyOEwbk2hCk',
#    'plus_code': {'compound_code': '9523+RR Luderitz, Namibia',
#     'global_code': '5F5Q9523+RR'},
#    'reference': 'ChIJNbXruHbnaxwRmyOEwbk2hCk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Schinz Street, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6498815, 'lng': 15.1540655},
#     'viewport': {'northeast': {'lat': -26.6484838197085,
#       'lng': 15.1554988302915},
#      'southwest': {'lat': -26.6511817802915, 'lng': 15.1528008697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Historical Guesthouse Krabbenhoft and Lampe',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106043569471707999357">Historical Guesthouse Krabbenhoft and Lampe</a>'],
#      'photo_reference': 'CmRaAAAAQjR5DTA35TexVrJI64Hb2HTF1zFnrd21r1mu-2A9niMUh1pUOer8V7ajq3aMGE4O5i1VT29zWvr3bZyDMdg1xsL0mbidueFxKVKTyALM2ocV_PcJz1Dn_4w7-A6nhWlrEhAIQ1O4pm-iUUoEYAhPEsm9GhQeytjP6asMrMrgMu37fKXoesW3PQ',
#      'width': 3264}],
#    'place_id': 'ChIJCRzOw5bmaxwRPtAIsWy_C9o',
#    'plus_code': {'compound_code': '9523+2J Luderitz, Namibia',
#     'global_code': '5F5Q9523+2J'},
#    'rating': 4.3,
#    'reference': 'ChIJCRzOw5bmaxwRPtAIsWy_C9o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 27,
#    'vicinity': '25 Bismarck Street, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6455133, 'lng': 15.1566267},
#     'viewport': {'northeast': {'lat': -26.6441307697085,
#       'lng': 15.1579353302915},
#      'southwest': {'lat': -26.6468287302915, 'lng': 15.1552373697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Luderitz Backpackers',
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107846850139639671422">Bjoern M</a>'],
#      'photo_reference': 'CmRaAAAAFSk68_2SV2BdDnuYgZ9tLXn2Z47e2YLqHGdJ2bVxkLX0Sx61GqhUFcGRAiBQuu1D7j7u-flfJvccRSVkk_WqhKU18QDKcgxfe9ddi9IxC05aDGDVXhP83T3d0MG-4OmUEhC-yhDW_I669oemF1Cc7ZeBGhR6ZvVipAzQKdT9DOXfcgjcVpT-6Q',
#      'width': 3264}],
#    'place_id': 'ChIJVfTWdJrmaxwRMm5ck8xWsiw',
#    'plus_code': {'compound_code': '9534+QM Luderitz, Namibia',
#     'global_code': '5F5Q9534+QM'},
#    'rating': 4.1,
#    'reference': 'ChIJVfTWdJrmaxwRMm5ck8xWsiw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': 'B4, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6492091, 'lng': 15.1539524},
#     'viewport': {'northeast': {'lat': -26.6478469197085,
#       'lng': 15.1553738302915},
#      'southwest': {'lat': -26.6505448802915, 'lng': 15.1526758697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'OceanLife Luderitz Accommodation',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112364404885469955172">Sab</a>'],
#      'photo_reference': 'CmRaAAAAIs2WD7URaaUn2mNWnq3RQuwqCyH4a94qKUxTYnfsmVnTWyqwkFweKvckpWdrqw1qLvLdIwI7qjRKxLHL8ievS9XL8EP_OoI-XEbns0zgFTUdXSVB1ZrOqlwVK8HIoMm7EhCweiaMGLzmujphUMec0wrcGhQBZ34MfzinIh0BBRw6eerunJ3UOw',
#      'width': 4160}],
#    'place_id': 'ChIJZWfm0MXnaxwRWO-Am7x56dw',
#    'plus_code': {'compound_code': '9523+8H Luderitz, Namibia',
#     'global_code': '5F5Q9523+8H'},
#    'rating': 3.7,
#    'reference': 'ChIJZWfm0MXnaxwRWO-Am7x56dw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 41,
#    'vicinity': '289 Bismarck, Luderitz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -26.6509391, 'lng': 15.1537292},
#     'viewport': {'northeast': {'lat': -26.6495793697085,
#       'lng': 15.1550658302915},
#      'southwest': {'lat': -26.6522773302915, 'lng': 15.1523678697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Zum Anker Apartments',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1225,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103163622457477813299">Zum Anker Apartments</a>'],
#      'photo_reference': 'CmRaAAAAI9leuBXjYCJgrWuF5J3iZXGoZEzEhoI-zPn4POIyGmeO2SZAbmKoUrHCrTNJ969nIl5XKz0ee6a1Hfa5OxeFvL_B8hsn6GI6Z6k9PaCvsiWT9vMO--bG6uQ3bJQE5C6ZEhBCjo5wRGnQLpaeuzxEO1BoGhT3KiwFlIQmzBfKdAMzZoLHyRHgdQ',
#      'width': 2048}],
#    'place_id': 'ChIJy_5TvZbmaxwR7v3KrJyQTIg',
#    'plus_code': {'compound_code': '85X3+JF Luderitz, Namibia',
#     'global_code': '5F5Q85X3+JF'},
#    'rating': 4.3,
#    'reference': 'ChIJy_5TvZbmaxwR7v3KrJyQTIg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 44,
#    'vicinity': '299 Bulow, Luderitz'}],
#  'status': 'OK'}

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{name}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
#hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#locations = hotel_df[["lat", "long"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8168f59695f9> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["lat", "long"]]
#
# NameError: name 'hotel_df' is not defined

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# Display figure
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-317fd869b1f7> in <module>
#       1 # Add marker layer ontop of heat map
# ----> 2 marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#       3 fig.add_layer(marker_layer)
#       4 # Display figure
#       5 fig
#
# NameError: name 'hotel_info' is not defined
